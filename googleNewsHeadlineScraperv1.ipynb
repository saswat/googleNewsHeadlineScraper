# %%
import requests
from bs4 import BeautifulSoup as bs4

# %%
url = "https://www.google.com/search?q=ibuprofen&hl=en&gl=us&authuser=0&tbs=qdr:y&tbm=nws&start=$count$&cad=h"
count=0

headlines = []
dates = []

while (count<100):
    new_url = url.replace("$count$", str(count))
    r = requests.get(new_url)
    
    soup = bs4(r.text, 'html.parser')
    headlines += soup.find_all("div", "st")
    dates += soup.find_all("div", "slp")
    print("ITEMS "+str(count)+ " THROUGH "+str(count+9))
    print(soup.prettify())
    url = "https://www.google.com/search?q=ibuprofen&hl=en&gl=us&authuser=0&tbs=qdr:y&tbm=nws&start=$count$&cad=h"
    count = count+10
# Out:
# ITEMS 0 THROUGH 9
# <!DOCTYPE doctype html>
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#    <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image">
#     <link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon">
#      <title>
#       ibuprofen - Google Search
#      </title>
#      <style>
#       #gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
#      </style>
#      <style>
# ...

# %%
print(headlines)
# Out:
# [<div class="st">I must start off by saying I love <b>ibuprofen</b>. I recommend it to the majority of people who inquire about pain medication because it works so well, it is inexpensive,\xa0...</div>, <div class="st">Common over-the-counter NSAIDs include <b>ibuprofen</b> (Motrin, Advil) and naproxen (Aleve), and people promptly freaked out over the news. But before you do\xa0...</div>, <div class="st">The <b>Ibuprofen</b> research report by QY Research represents an inclusive evaluation of the Global <b>Ibuprofen</b> Market and comprises considerable insights, historical\xa0...</div>, <div class="st">The recent report of Market Research Store on the \u201c<b>Ibuprofen</b> Market Research\u201d has the complete assessment of the latest trends of the global <b>Ibuprofen</b> market.</div>, <div class="st"><b>Ibuprofen</b> is one of the most common medicines used to counter pain. But, Doctors are urging people that are over the age of 40 to stop taking this drug. A major\xa0...</div>,
# ...

# %%
print(dates)
# Out:
# [<div class="slp"><span class="f">Pharmacy Times - 5 days ago</span></div>, <div class="slp"><span class="f">SELF - May 30, 2017</span></div>, <div class="slp"><span class="f">Queens Tribune - 22 hours ago</span></div>, <div class="slp"><span class="f">Medgadget (blog) - 3 days ago</span></div>, <div class="slp"><span class="f">World Of WallStreet - 4 days ago</span></div>, <div class="slp"><span class="f">PagalParrot - Jun 16, 2017</span></div>, <div class="slp"><span class="f">Science Daily - Jun 19, 2017</span></div>, <div class="slp"><span class="f">CBS News - Jun 15, 2017</span></div>, <div class="slp"><span class="f">Pharmacy News - Jun 6, 2017</span></div>, <div class="slp"><span class="f">Medgadget (blog) - Jun 16, 2017</span></div>, <div class="slp"><span class="f">Mental Floss - 6 days ago</span></div>, <div class="slp"><span class="f">Chemist+Druggist - 2 hours ago</span></div>, <div class="slp"><span class="f">Spectrum - 5 hours ago</span></div>, <div class="slp"><span cl
# ...
